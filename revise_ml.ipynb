# %% [markdown]
# <a href="https://colab.research.google.com/github/Sundar-9786/Colab_works/blob/main/revise_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("helo world")
# Out:
# helo world

# %%
def count():
    for i in range(300):
        print(i,"sundar",end="\n")

k= count()

# %%
adad
